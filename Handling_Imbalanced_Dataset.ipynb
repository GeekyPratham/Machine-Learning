# %% [markdown]
# Imbalanced Dataset
#
# A dataset with an unequal class distribution

# %%
# importing the dependencies
import pandas as pd
import numpy as np

# %%
#loading the dataset to pandas Dataframe
credit_card_data = pd.read_csv('/content/drive/MyDrive/datasets/credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#distribution of the two classes of dataset
credit_card_data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# this is highly imbalanced data set as because more than 95% of data belogns to one class
#
# 0 -> legit transaction
#
# 1-> fraudulent transaction

# %%
# seperating the legit and fraudulent transaction
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print(fraud)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# Under-Sampling
#
# taking the data from maximaum data of which group presnt approximatly the lower data

# %% [markdown]
# Build a sample dataset containing similar distribution of legit and fraudulent transactions

# %% [markdown]
# Number of Fraudulent Transaction - 492

# %%
legit_sample = legit.sample(n=492)

# %%
print(legit_sample)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 151154   94798.0 -0.840346  1.624723  0.378213 -0.763245  0.756079 -0.912205
# 108251   70825.0  1.096603 -0.061721  0.481044  1.314472 -0.442788 -0.174376
# 194385  130559.0 -0.103491  1.175988 -0.375584 -0.563498  0.842842 -0.802889
# 236573  148868.0  0.675735 -4.350687 -1.634644 -1.013566 -1.887550  1.239164
# 277077  167446.0 -0.262735  0.746264  0.906820 -0.887801  0.882195 -0.482830
# ...          ...       ...       ...       ...       ...       ...       ...
# 119658   75535.0 -5.738966 -7.253701 -0.052410  2.412767  1.916644 -1.538181
# 66019    51845.0 -3.543386  0.347750  1.742098  3.289704 -1.030883  1.128970
# 277990  167975.0  1.844204  0.001440 -4.376342 -0.314203  3.181545  2.565335
# 183368  125766.0 -0.415163  0.933262  0.060306  0.569671 -1.268111 -0.079642
# 242786  151648.0  1.931383 -0.444180 -0.425644 -0.042563 -0.426833  0.008286
#
# ...

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# #concatenate the two dataframe i.e legit_sample + fraud

# %%
new_dataset = pd.concat([legit_sample,fraud], axis = 0)

# %%
print(new_dataset)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 151154   94798.0 -0.840346  1.624723  0.378213 -0.763245  0.756079 -0.912205
# 108251   70825.0  1.096603 -0.061721  0.481044  1.314472 -0.442788 -0.174376
# 194385  130559.0 -0.103491  1.175988 -0.375584 -0.563498  0.842842 -0.802889
# 236573  148868.0  0.675735 -4.350687 -1.634644 -1.013566 -1.887550  1.239164
# 277077  167446.0 -0.262735  0.746264  0.906820 -0.887801  0.882195 -0.482830
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 151154   94798.0 -0.840346  1.624723  0.378213 -0.763245  0.756079 -0.912205
# 108251   70825.0  1.096603 -0.061721  0.481044  1.314472 -0.442788 -0.174376
# 194385  130559.0 -0.103491  1.175988 -0.375584 -0.563498  0.842842 -0.802889
# 236573  148868.0  0.675735 -4.350687 -1.634644 -1.013566 -1.887550  1.239164
# 277077  167446.0 -0.262735  0.746264  0.906820 -0.887801  0.882195 -0.482830
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 151154  1.621163 -0.955459  2.448033  ... -0.712967 -0.661023  0.021933
# 108251 -0.103768  0.104963  0.669769  ... -0.174544 -0.426346 -0.001991
# 194385  1.066699 -0.245090  0.041354  ...  0.338545  1.320448 -0.107148
# 236573 -0.658408  0.112412 -0.648933  ... -0.079027 -1.497425 -0.360629
# 277077  1.241387 -0.281613 -0.479067  ... -0.236774 -0.525931 -0.184440
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset.Class.value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64
