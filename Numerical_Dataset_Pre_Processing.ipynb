# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler # for datandardize the data
from sklearn.model_selection import train_test_split # for spliting the data into train and test data
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection & Pre-Processing

# %%
#loading the data from csv file to a pandas dataframe
diabetes_data = pd.read_csv('/content/drive/MyDrive/datasets/diabetes.csv')

# %%
# printing first five rows
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Separating features and target

# %%
X = diabetes_data.drop(columns = 'Outcome' ,axis = 1);
Y =diabetes_data.Outcome

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(X.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# 0 -> non diabetic
#
#
# 1 -> diabetic

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %% [markdown]
# Here we above see that the data is not standardize as some are pragnancies ranges from (0 to 20) and Glucose ranges from (50 to 400) and diabetesPedigreeFunction ranges in (<0)

# %% [markdown]
# Data Standardization

# %% [markdown]
# so we will transform all the data in common range
# so we use function standardScaler

# %%
scaler = StandardScaler()

# %%
standardize_data = scaler.fit_transform(X)

# %%
print(standardize_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = pd.DataFrame(standardize_data)

# %%
print(X)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.639947  0.848324  0.149641  0.907270 -0.692891  0.204013  0.468492
# 1   -0.844885 -1.123396 -0.160546  0.530902 -0.692891 -0.684422 -0.365061
# 2    1.233880  1.943724 -0.263941 -1.288212 -0.692891 -1.103255  0.604397
# 3   -0.844885 -0.998208 -0.160546  0.154533  0.123302 -0.494043 -0.920763
# 4   -1.141852  0.504055 -1.504687  0.907270  0.765836  1.409746  5.484909
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  1.827813 -0.622642  0.356432  1.722735  0.870031  0.115169 -0.908682
# 764 -0.547919  0.034598  0.046245  0.405445 -0.692891  0.610154 -0.398282
# 765  0.342981  0.003301  0.149641  0.154533  0.279594 -0.735190 -0.685193
# 766 -0.844885  0.159787 -0.470732 -1.288212 -0.692891 -0.240205 -0.371101
# 767 -0.844885 -0.873019  0.046245  0.656358 -0.692891 -0.202129 -0.473785
#
#             7
# 0    1.425995
# 1   -0.190672
# 2   -0.105584
# 3   -1.041549
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Splitting the dataset into train  and test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (768,) (614,) (154,)
